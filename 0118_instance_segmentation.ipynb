# %%
pip install imageio
# Out:
# Requirement already satisfied: imageio in /opt/conda/envs/sds2021/lib/python3.9/site-packages (2.9.0)
# Requirement already satisfied: pillow in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from imageio) (9.3.0)
# Requirement already satisfied: numpy in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from imageio) (1.21.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mxnet==1.6.0
# Out:
# Requirement already satisfied: mxnet==1.6.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (1.6.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from mxnet==1.6.0) (1.21.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from mxnet==1.6.0) (0.8.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from mxnet==1.6.0) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet==1.6.0) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet==1.6.0) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet==1.6.0) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet==1.6.0) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
from gluoncv import model_zoo, data, utils

# %%
net = model_zoo.get_model('mask_rcnn_resnet50_v1b_coco', pretrained=True)

# %%
im_fname = utils.download('https://github.com/dmlc/web-data/blob/master/' +
                          'gluoncv/detection/biking.jpg?raw=true',
                          path='biking.jpg')
x, orig_img = data.transforms.presets.rcnn.load_test(im_fname)

# %%
ids, scores, bboxes, masks = [xx[0].asnumpy() for xx in net(x)]

# paint segmentation mask on images directly
width, height = orig_img.shape[1], orig_img.shape[0]

masks, _ = utils.viz.expand_mask(masks, bboxes, (width, height), scores)

orig_img = utils.viz.plot_mask(orig_img, masks)


# identical to Faster RCNN object detection
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(1, 1, 1)

ax = utils.viz.plot_bbox(orig_img, bboxes, scores, ids,
                         class_names=net.classes, ax=ax)
plt.show()

# %%
pip install label-studio
# Out:
# Requirement already satisfied: label-studio in /opt/conda/envs/sds2021/lib/python3.9/site-packages (1.7.1)
# Requirement already satisfied: lxml>=4.2.5 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (4.9.2)
# Requirement already satisfied: google-cloud-storage~=2.5.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.5.0)
# Requirement already satisfied: django-model-utils==4.1.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (4.1.1)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.2.0)
# Requirement already satisfied: google-cloud-appengine-logging==1.1.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.1.0)
# Requirement already satisfied: django-storages==1.12.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.12.3)
# Requirement already satisfied: colorama>=0.4.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.4.4)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.14.0)
# Requirement already satisfied: ordered-set==4.0.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (4.0.2)
# Requirement already satisfied: requests<2.28,>=2.22.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.26.0)
# Requirement already satisfied: attr==0.3.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.3.1)
# Requirement already satisfied: django-annoying==0.10.6 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.10.6)
# Requirement already satisfied: drf-yasg==1.20.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.20.0)
# Requirement already satisfied: rq==1.10.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.10.1)
# Requirement already satisfied: django-debug-toolbar==3.2.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.2.1)
# Requirement already satisfied: rules==2.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.2)
# Requirement already satisfied: google-cloud-logging~=2.7.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.7.2)
# Requirement already satisfied: bleach~=5.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (5.0.1)
# Requirement already satisfied: pytz~=2019.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2019.3)
# Requirement already satisfied: boto~=2.49.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.49.0)
# Requirement already satisfied: redis>=4.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (4.4.2)
# Requirement already satisfied: defusedxml>=0.7.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.7.1)
# Requirement already satisfied: django-cors-headers==3.6.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.6.0)
# Requirement already satisfied: xmljson==0.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.2.0)
# Requirement already satisfied: drf-dynamic-fields==0.3.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: googleapis-common-protos==1.56.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.56.4)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.4.4)
# Requirement already satisfied: protobuf>=3.15.5 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.20.3)
# Requirement already satisfied: django-extensions==3.1.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.1.0)
# Requirement already satisfied: django-ranged-fileresponse>=0.1.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.1.2)
# Requirement already satisfied: pydantic<=1.8.2,>=1.7.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.8.2)
# Requirement already satisfied: google-resumable-media==2.3.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.3.3)
# Requirement already satisfied: google-auth==2.11.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.11.0)
# Requirement already satisfied: django-filter==2.4.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.4.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.8.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (21.2.0)
# Requirement already satisfied: wheel in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.36.2)
# Requirement already satisfied: google-cloud-audit-log==0.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.2.0)
# Requirement already satisfied: launchdarkly-server-sdk==7.5.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (7.5.0)
# Requirement already satisfied: ujson>=3.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (4.0.2)
# Requirement already satisfied: Django==3.2.16 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.2.16)
# Requirement already satisfied: python-json-logger==2.0.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.0.4)
# Requirement already satisfied: django-rest-swagger==2.2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.2.0)
# Requirement already satisfied: django-user-agents==0.4.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.4.0)
# Requirement already satisfied: boxing>=0.1.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.1.4)
# Requirement already satisfied: botocore~=1.19.28 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.19.63)
# Requirement already satisfied: label-studio-converter==0.0.48rc0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.0.48rc0)
# Requirement already satisfied: drf-generators==0.3.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: psycopg2-binary==2.9.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.9.1)
# Requirement already satisfied: djangorestframework==3.13.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (3.13.1)
# Requirement already satisfied: numpy>=1.19.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.21.1)
# Requirement already satisfied: boto3~=1.16.28 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.16.63)
# Requirement already satisfied: lockfile>=0.12.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.12.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (1.3.0)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.1.12)
# Requirement already satisfied: google-api-core==2.10.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.10.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (12.14.1)
# Requirement already satisfied: django-rq==2.5.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.5.1)
# Requirement already satisfied: grpc-google-iam-v1==0.12.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.12.3)
# Requirement already satisfied: drf-flex-fields==0.9.5 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (0.9.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (5.4.1)
# Requirement already satisfied: google-cloud-core==2.3.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio) (2.3.2)
# Requirement already satisfied: sqlparse>=0.2.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from Django==3.2.16->label-studio) (0.4.3)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from Django==3.2.16->label-studio) (3.6.0)
# Requirement already satisfied: six in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from django-annoying==0.10.6->label-studio) (1.16.0)
# Requirement already satisfied: coreapi>=2.3.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from django-rest-swagger==2.2.0->label-studio) (2.3.3)
# Requirement already satisfied: openapi-codec>=1.3.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from django-rest-swagger==2.2.0->label-studio) (1.3.2)
# Requirement already satisfied: simplejson in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from django-rest-swagger==2.2.0->label-studio) (3.17.3)
# Requirement already satisfied: user-agents in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from django-user-agents==0.4.0->label-studio) (2.2.0)
# Requirement already satisfied: packaging in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from drf-yasg==1.20.0->label-studio) (21.0)
# Requirement already satisfied: coreschema>=0.0.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from drf-yasg==1.20.0->label-studio) (0.0.4)
# Requirement already satisfied: inflection>=0.3.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from drf-yasg==1.20.0->label-studio) (0.5.1)
# Requirement already satisfied: uritemplate>=3.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from drf-yasg==1.20.0->label-studio) (4.1.1)
# Requirement already satisfied: ruamel.yaml>=0.15.34 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from drf-yasg==1.20.0->label-studio) (0.17.21)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-auth==2.11.0->label-studio) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-auth==2.11.0->label-studio) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-auth==2.11.0->label-studio) (4.2.2)
# Requirement already satisfied: proto-plus>=1.15.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-cloud-appengine-logging==1.1.0->label-studio) (1.22.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-resumable-media==2.3.3->label-studio) (1.5.0)
# Requirement already satisfied: grpcio<2.0.0dev,>=1.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from grpc-google-iam-v1==0.12.3->label-studio) (1.51.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from jsonschema==3.2.0->label-studio) (0.17.3)
# Requirement already satisfied: setuptools in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from jsonschema==3.2.0->label-studio) (49.6.0.post20210108)
# Requirement already satisfied: label-studio-tools==0.0.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio-converter==0.0.48rc0->label-studio) (0.0.1)
# Requirement already satisfied: Pillow==9.3.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio-converter==0.0.48rc0->label-studio) (9.3.0)
# Requirement already satisfied: nltk==3.6.7 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from label-studio-converter==0.0.48rc0->label-studio) (3.6.7)
# Requirement already satisfied: pyRFC3339>=1.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from launchdarkly-server-sdk==7.5.0->label-studio) (1.1)
# Requirement already satisfied: semver<3.0.0,>=2.10.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from launchdarkly-server-sdk==7.5.0->label-studio) (2.13.0)
# Requirement already satisfied: urllib3>=1.22.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from launchdarkly-server-sdk==7.5.0->label-studio) (1.26.14)
# Requirement already satisfied: certifi>=2018.4.16 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from launchdarkly-server-sdk==7.5.0->label-studio) (2021.5.30)
# Requirement already satisfied: expiringdict>=1.1.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from launchdarkly-server-sdk==7.5.0->label-studio) (1.2.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from nltk==3.6.7->label-studio-converter==0.0.48rc0->label-studio) (2022.10.31)
# Requirement already satisfied: click in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from nltk==3.6.7->label-studio-converter==0.0.48rc0->label-studio) (7.1.2)
# Requirement already satisfied: tqdm in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from nltk==3.6.7->label-studio-converter==0.0.48rc0->label-studio) (4.61.2)
# Requirement already satisfied: joblib in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from nltk==3.6.7->label-studio-converter==0.0.48rc0->label-studio) (1.2.0)
# Requirement already satisfied: msrest>=0.7.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from azure-storage-blob>=12.6.0->label-studio) (0.7.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from azure-storage-blob>=12.6.0->label-studio) (1.26.2)
# Requirement already satisfied: cryptography>=2.1.4 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from azure-storage-blob>=12.6.0->label-studio) (3.4.7)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.2->azure-storage-blob>=12.6.0->label-studio) (4.4.0)
# Requirement already satisfied: webencodings in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from bleach~=5.0.0->label-studio) (0.5.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from boto3~=1.16.28->label-studio) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from boto3~=1.16.28->label-studio) (0.3.7)
# Requirement already satisfied: itypes in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from coreapi>=2.3.0->django-rest-swagger==2.2.0->label-studio) (1.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from coreschema>=0.0.4->drf-yasg==1.20.0->label-studio) (3.0.1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.6.0->label-studio) (1.14.6)
# Requirement already satisfied: pycparser in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.6.0->label-studio) (2.20)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from google-api-core==2.10.0->label-studio) (1.48.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-blob>=12.6.0->label-studio) (1.3.1)
# Requirement already satisfied: isodate>=0.6.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from msrest>=0.7.1->azure-storage-blob>=12.6.0->label-studio) (0.6.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from packaging->drf-yasg==1.20.0->label-studio) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth==2.11.0->label-studio) (0.4.8)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from redis>=4.2.0->label-studio) (4.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<2.28,>=2.22.0->label-studio) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests<2.28,>=2.22.0->label-studio) (3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.1->azure-storage-blob>=12.6.0->label-studio) (3.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from ruamel.yaml>=0.15.34->drf-yasg==1.20.0->label-studio) (0.2.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from jinja2->coreschema>=0.0.4->drf-yasg==1.20.0->label-studio) (2.1.1)
# Requirement already satisfied: ua-parser>=0.10.0 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from user-agents->django-user-agents==0.4.0->label-studio) (0.16.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install labelme
# Out:
# Collecting labelme
#   Downloading labelme-5.1.1.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 6.6 MB/s eta 0:00:01
# Collecting imgviz>=0.11
#   Downloading imgviz-1.6.2.tar.gz (7.7 MB)
#      |████████████████████████████████| 7.7 MB 5.6 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: matplotlib in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from labelme) (3.4.2)
# Collecting natsort>=7.1.0
#   Downloading natsort-8.2.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from labelme) (1.21.1)
# Requirement already satisfied: Pillow>=2.8 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from labelme) (9.3.0)
# Requirement already satisfied: PyYAML in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from labelme) (5.4.1)
# Collecting qtpy!=1.11.2
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: termcolor in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from labelme) (2.1.1)
# Requirement already satisfied: packaging in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from qtpy!=1.11.2->labelme) (21.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from matplotlib->labelme) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from matplotlib->labelme) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from matplotlib->labelme) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from matplotlib->labelme) (2.8.1)
# Requirement already satisfied: six in /opt/conda/envs/sds2021/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->labelme) (1.16.0)
# Building wheels for collected packages: labelme, imgviz
#   Building wheel for labelme (setup.py) ... done
#   Created wheel for labelme: filename=labelme-5.1.1-py3-none-any.whl size=1466341 sha256=1a375ea272feef15764df55f06908377c9788a57f821d91fb11738449026d679
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f7/dd/4b/aa34a2cc4e9a53f43b682ee3e74ab03e877f37cc36c67ea099
#   Building wheel for imgviz (PEP 517) ... done
#   Created wheel for imgviz: filename=imgviz-1.6.2-py3-none-any.whl size=7681446 sha256=0f0b0944bf77f2f11f7bcfba535dd87036f95d19f420be17c3c4433a5b7ea5cf
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e5/b0/ae/22e483d67fcaa383b4cc29446395323653f946b5a1fe28be32
# Successfully built labelme imgviz
# Installing collected packages: qtpy, natsort, imgviz, labelme
# Successfully installed imgviz-1.6.2 labelme-5.1.1 natsort-8.2.0 qtpy-2.3.0
# Note: you may need to restart the kernel to use updated packages.
